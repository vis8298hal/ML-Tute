# %% [markdown]
# # 1. Create a simple line plot for the following data:
#
#   x = [1, 2, 3, 4, 5]
#   y = [10, 15, 25, 30, 50]
#
#
#   a. Plot the data.
#   b. Customize the plot by adding a title, axis labels, and a grid.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [10, 15, 25, 30, 50]

# %%
fig = plt.figure(figsize=(6,3))
plt.plot(x, y)
plt.title("Simple Line Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.xticks(x)
plt.yticks(y)
plt.grid()
plt.show()

# %% [markdown]
#  # 2. Create a bar graph to represent the marks scored by students in a subject:
#
#   students = ['John', 'Jane', 'Alice', 'Bob']
#   marks = [75, 85, 60, 90]
#
#   a. Plot the data as a bar graph.
#   b. Customize the colors and add a title.

# %%
students = ['John', 'Jane', 'Alice', 'Bob']
marks = [75, 85, 60, 90]

# %%
fig = plt.figure(figsize=(6,3))
plt.bar(students, marks, color=["blue", "red", "green", "orange"])
plt.title("Student's Performances")
plt.xlabel("Students")
plt.ylabel("Marks Obtained")
plt.show()

# %% [markdown]
# # 3. Create a pie chart to represent the percentage distribution of a company’s revenue from different regions:
#
#   regions = ['North America', 'Europe', 'Asia', 'Others']
#   revenue = [45, 25, 20, 10]
#
#   a. Create a pie chart with the region names as labels.
#   b. Highlight the region with the highest revenue.

# %%
regions = ['North America', 'Europe', 'Asia', 'Others']
revenue = [45, 25, 20, 10]

# %%
fig = plt.figure(figsize=(6,3))
explode = [0.1 if i == max(revenue) else 0 for i in revenue]
plt.pie(revenue, labels=regions, autopct="%.2f", shadow=True, explode=explode)
plt.show()

# %%
# Explode is a Highlighting Array Which contains positive value for the Index of Data to be highlighted Which is North America in this Case

# %% [markdown]
# # 4. Generate a histogram to show the frequency distribution of randomly generated integers between 1 and 100 (sample size = 1000).

# %%
x = np.random.randint(1, 100, 1000)

# %%
#Above Code was to Generate the Sample Data

# %%
fig = plt.figure(figsize=(6,3))
plt.hist(x, bins=100)
plt.show()
